# %% [markdown]
# <a href="https://colab.research.google.com/github/RylleLang/MANTARING_RYLLE_AIRO_CPE311N/blob/main/Copy_of_TOH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Tower of Hanoi is a mathematical puzzle invented by the French mathematician Edouard LucasLinks to an external site. in 1883.
#
# There are three pegs, source(A), Auxiliary (B) and Destination(C). Peg A contains a set of disks stacked to resemble a tower, with the largest disk at the bottom and the smallest disk at the top. figure 1 Illustrate the initial configuration of the pegs for 3 disks. The objective is to transfer the entire tower of disks in peg A to peg C maintaining the same order of the disks.
#
# Obeying the following rules:
#
# Only one disk can be transfer at a time.
# Each move consists of taking the upper disk from one of the peg and placing it on the top of another peg i.e. a disk can only be moved if it is the uppermost disk of the peg.
# Never a larger disk is placed on a smaller disk during the transfer.

# %% [markdown]
# **Procedure**
#
# Implement the algorithm for the Tower of Hanoi Problem as shown above.
# Write your observations for your written algorithm/solution.

# %%
#RylleMantaring
def TOH(n, Sour, Aux, Des):
    if(n == 1):  # if the number is equal to 1 will print below
        print('Move the ring 1 from stand {} to stand {}'.format(Sour, Des))
        return # if not euqal to 1 continue to below
    TOH(n - 1, Sour, Des, Aux)
    print('Move the ring {} from stand {} to stand {}'.format(n, Sour, Des))
    TOH(n - 1, Aux, Sour, Des)  # if not euqal go again to top


n2 = int(input("Numbers of rings: ")) #input
TOH(n2, 'A', 'B', 'C') #inputs
# Out:
# Numbers of rings: 5
# Move the ring 1 from stand A to stand C
# Move the ring 2 from stand A to stand B
# Move the ring 1 from stand C to stand B
# Move the ring 3 from stand A to stand C
# Move the ring 1 from stand B to stand A
# Move the ring 2 from stand B to stand C
# Move the ring 1 from stand A to stand C
# Move the ring 4 from stand A to stand B
# Move the ring 1 from stand C to stand B
# Move the ring 2 from stand C to stand A
# Move the ring 1 from stand B to stand A
# Move the ring 3 from stand C to stand B
# Move the ring 1 from stand A to stand C
# Move the ring 2 from stand A to stand B
# Move the ring 1 from stand C to stand B
# Move the ring 5 from stand A to stand C
# Move the ring 1 from stand B to stand A
# Move the ring 2 from stand B to stand C
# Move the ring 1 from stand A to stand C
# Move the ring 3 from stand B to stand A
# Move the ring 1 from stand C to stand B
# Move the ring 2 from stand C to stand A
# Move the ring 1 from stand B to stand A
# Move the ring 4 from stand B to stand C
# Move the ring 1 from stand A to stand C
# Move the ring 2 from stand A to stand B
# Move the ring 1 from stand C to stand B
# Move the ring 3 from stand A to stand C
# Move the ring 1 from stand B to stand A
# Move the ring 2 from stand B to stand C
# Move the ring 1 from stand A to stand C

# %% [markdown]
# **Supplementary Activity**
#
# Explain the programming paradigms/techniques (like recursion or dynamic programming) that you used to solve the given problem.
#
# My answer: It's possibly uses a recursion because i see that the ability to solve a problem by breaking it down into smaller sub-problems is used in this scenario
# Provide screenshots of the techniques and provide a quick analysis.

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)
