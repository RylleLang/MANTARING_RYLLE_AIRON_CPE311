# %% [markdown]
# <a href="https://colab.research.google.com/github/RylleLang/MANTARING_RYLLE_AIRO_CPE311N/blob/main/quizMidterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.6-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.6

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
rt_iot2022 = fetch_ucirepo(id=942)

# data (as pandas dataframes)
X = rt_iot2022.data.features
y = rt_iot2022.data.targets

# metadata
rt_iot2022.metadata

# variable information
z=rt_iot2022.variables

# %%
merge_datas = pd.concat([z, y, X], ignore_index = True, sort =False)

# %%
merge_datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246319 entries, 0 to 246318
# Data columns (total 91 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   name                      85 non-null      object
#  1   role                      85 non-null      object
#  2   type                      85 non-null      object
#  3   demographic               0 non-null       object
#  4   description               0 non-null       object
#  5   units                     0 non-null       object
#  6   missing_values            85 non-null      object
#  7   Attack_type               123117 non-null  object
#  8   id.orig_p                 123117 non-null  float64
#  9   id.resp_p                 123117 non-null  float64
#  10  proto                     123117 non-null  object
#  11  service                   123117 non-null  object
#  12  flow_duration             123117 non-null  float64
#  13  fwd_pkts_tot              123117 non-null  float64
#  14  bwd_pkts_tot              123117 non-null  float64
#  15  fwd_data_pkts_tot         123117 non-null  float64
#  16  bwd_data_pkts_tot         123117 non-null  float64
#  17  fwd_pkts_per_sec          123117 non-null  float64
#  18  bwd_pkts_per_sec          123117 non-null  float64
#  19  flow_pkts_per_sec         123117 non-null  float64
#  20  down_up_ratio             123117 non-null  float64
#  21  fwd_header_size_tot       123117 non-null  float64
#  22  fwd_header_size_min       123117 non-null  float64
#  23  fwd_header_size_max       123117 non-null  float64
#  24  bwd_header_size_tot       123117 non-null  float64
#  25  bwd_header_size_min       123117 non-null  float64
#  26  bwd_header_size_max       123117 non-null  float64
#  27  flow_FIN_flag_count       123117 non-null  float64
#  28  flow_SYN_flag_count       123117 non-null  float64
#  29  flow_RST_flag_count       123117 non-null  float64
#  30  fwd_PSH_flag_count        123117 non-null  float64
#  31  bwd_PSH_flag_count        123117 non-null  float64
#  32  flow_ACK_flag_count       123117 non-null  float64
#  33  fwd_URG_flag_count        123117 non-null  float64
#  34  bwd_URG_flag_count        123117 non-null  float64
#  35  flow_CWR_flag_count       123117 non-null  float64
#  36  flow_ECE_flag_count       123117 non-null  float64
#  37  fwd_pkts_payload.min      123117 non-null  float64
#  38  fwd_pkts_payload.max      123117 non-null  float64
#  39  fwd_pkts_payload.tot      123117 non-null  float64
#  40  fwd_pkts_payload.avg      123117 non-null  float64
#  41  fwd_pkts_payload.std      123117 non-null  float64
#  42  bwd_pkts_payload.min      123117 non-null  float64
#  43  bwd_pkts_payload.max      123117 non-null  float64
#  44  bwd_pkts_payload.tot      123117 non-null  float64
#  45  bwd_pkts_payload.avg      123117 non-null  float64
#  46  bwd_pkts_payload.std      123117 non-null  float64
#  47  flow_pkts_payload.min     123117 non-null  float64
#  48  flow_pkts_payload.max     123117 non-null  float64
#  49  flow_pkts_payload.tot     123117 non-null  float64
#  50  flow_pkts_payload.avg     123117 non-null  float64
#  51  flow_pkts_payload.std     123117 non-null  float64
#  52  fwd_iat.min               123117 non-null  float64
#  53  fwd_iat.max               123117 non-null  float64
#  54  fwd_iat.tot               123117 non-null  float64
#  55  fwd_iat.avg               123117 non-null  float64
#  56  fwd_iat.std               123117 non-null  float64
#  57  bwd_iat.min               123117 non-null  float64
#  58  bwd_iat.max               123117 non-null  float64
#  59  bwd_iat.tot               123117 non-null  float64
#  60  bwd_iat.avg               123117 non-null  float64
#  61  bwd_iat.std               123117 non-null  float64
#  62  flow_iat.min              123117 non-null  float64
#  63  flow_iat.max              123117 non-null  float64
#  64  flow_iat.tot              123117 non-null  float64
#  65  flow_iat.avg              123117 non-null  float64
#  66  flow_iat.std              123117 non-null  float64
#  67  payload_bytes_per_second  123117 non-null  float64
#  68  fwd_subflow_pkts          123117 non-null  float64
#  69  bwd_subflow_pkts          123117 non-null  float64
#  70  fwd_subflow_bytes         123117 non-null  float64
#  71  bwd_subflow_bytes         123117 non-null  float64
#  72  fwd_bulk_bytes            123117 non-null  float64
#  73  bwd_bulk_bytes            123117 non-null  float64
#  74  fwd_bulk_packets          123117 non-null  float64
#  75  bwd_bulk_packets          123117 non-null  float64
#  76  fwd_bulk_rate             123117 non-null  float64
#  77  bwd_bulk_rate             123117 non-null  float64
#  78  active.min                123117 non-null  float64
#  79  active.max                123117 non-null  float64
#  80  active.tot                123117 non-null  float64
#  81  active.avg                123117 non-null  float64
#  82  active.std                123117 non-null  float64
#  83  idle.min                  123117 non-null  float64
#  84  idle.max                  123117 non-null  float64
#  85  idle.tot                  123117 non-null  float64
#  86  idle.avg                  123117 non-null  float64
#  87  idle.std                  123117 non-null  float64
#  88  fwd_init_window_size      123117 non-null  float64
#  89  bwd_init_window_size      123117 non-null  float64
#  90  fwd_last_window_size      123117 non-null  float64
# dtypes: float64(81), object(10)
# memory usage: 171.0+ MB

# %%
merge_datas.isnull().sum()
# Out:
# name                    246234
# role                    246234
# type                    246234
# demographic             246319
# description             246319
#                          ...
# idle.avg                123202
# idle.std                123202
# fwd_init_window_size    123202
# bwd_init_window_size    123202
# fwd_last_window_size    123202
# Length: 91, dtype: int64

# %%
X = merge_datas.drop(['Attack_type'],axis=1)
y = merge_datas['Attack_type']
X = pd.get_dummies(X)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  GridSearchCV

figure = plt.subplots(figsize=(20,6))
sns.countplot(data=merge_datas,x=merge_datas['Attack_type'],order=merge_datas['Attack_type'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
merge_datas.head()
# Out:
#             name     role         type demographic description units  \
# 0      id.orig_p  Feature      Integer        None        None  None
# 1      id.resp_p  Feature      Integer        None        None  None
# 2          proto  Feature  Categorical        None        None  None
# 3        service  Feature   Continuous        None        None  None
# 4  flow_duration  Feature   Continuous        None        None  None
#
#   missing_values Attack_type  id.orig_p  id.resp_p  ... active.avg active.std  \
# 0             no         NaN        NaN        NaN  ...        NaN        NaN
# 1             no         NaN        NaN        NaN  ...        NaN        NaN
# 2             no         NaN        NaN        NaN  ...        NaN        NaN
# 3             no         NaN        NaN        NaN  ...        NaN        NaN
# 4             no         NaN        NaN        NaN  ...        NaN        NaN
#
#    idle.min  idle.max  idle.tot  idle.avg  idle.std  fwd_init_window_size  \
# 0       NaN       NaN       NaN       NaN       NaN                   NaN
# 1       NaN       NaN       NaN       NaN       NaN                   NaN
# 2       NaN       NaN       NaN       NaN       NaN                   NaN
# 3       NaN       NaN       NaN       NaN       NaN                   NaN
# 4       NaN       NaN       NaN       NaN       NaN                   NaN
#
#    bwd_init_window_size  fwd_last_window_size
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
# [5 rows x 91 columns]

# %%
figure = plt.subplots(figsize=(20,6))
sns.countplot(data=merge_datas,x=merge_datas['proto'],order=merge_datas['proto'].value_counts().index)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y = le.fit_transform(y)
# Scaling the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.neural_network import MLPClassifier

Mlp = MLPClassifier(hidden_layer_sizes=(10, 10), activation='relu', solver='adam', random_state=42)
Mlp.fit(X, y)

y_pred = Mlp.predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-cbed3b5c6800> in <cell line: 4>()
#       2
#       3 Mlp = MLPClassifier(hidden_layer_sizes=(10, 10), activation='relu', solver='adam', random_state=42)
# ----> 4 Mlp.fit(X, y)
#       5
#       6 y_pred = Mlp.predict(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in fit(self, X, y)
#     747         self._validate_params()
#     748
# --> 749         return self._fit(X, y, incremental=False)
#     750
#     751     def _check_solver(self):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     435         )
#     436
# --> 437         X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     438
#     439         n_samples, n_features = X.shape
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in _validate_input(self, X, y, incremental, reset)
#    1087
#    1088     def _validate_input(self, X, y, incremental, reset):
# -> 1089         X, y = self._validate_data(
#    1090             X,
#    1091             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input X contains NaN.
# MLPClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

classification_report_op = classification_report(y_test, y_pred)
print("\nClassification Report:\n", classification_report_op)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-54619686235f> in <cell line: 3>()
#       1 from sklearn.metrics import accuracy_score, classification_report
#       2
# ----> 3 accuracy = accuracy_score(y_test, y_pred)
#       4 print("Accuracy:", accuracy)
#       5
#
# NameError: name 'y_pred' is not defined
