# %% [markdown]
# <a href="https://colab.research.google.com/github/RylleLang/MANTARING_RYLLE_AIRO_CPE311N/blob/main/Seatwork_6_1_Exploratory_Data_Analysis_on_Your_Own_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seatwork 6.1 Exploratory Data Analysis on Your Own Dataset
# **CPE311 Computational Thinking with Python**
#
# *   Name: Mantaring, RylleAiron J.
# *   Section: CPE22S3
# * Performed on: 03/11/2024
# * Submitted on: 03/11/2024
# * Submitted to: Engr. Roman M. Richard

# %%
filepath = '/content/credits.csv'
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(filepath)
data
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('Card Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
crd= pd.DataFrame(data)
crd.dtypes #dtypes to know the data type of a column
# Out:
# index         int64
# City         object
# Date         object
# Card Type    object
# Exp Type     object
# Gender       object
# Amount        int64
# dtype: object

# %%
crd.head(10) # to identify the first rows and the 10 is the numbers of row to be get
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574
# 5      5           Delhi, India   8-Sep-14     Silver    Bills      F  100036
# 6      6           Delhi, India  24-Feb-15       Gold    Bills      F  143250
# 7      7  Greater Mumbai, India  26-Jun-14   Platinum    Bills      F  150980
# 8      8           Delhi, India  28-Mar-14     Silver    Bills      F  192247
# 9      9           Delhi, India   1-Sep-14   Platinum    Bills      F   67932

# %%
crd.tail() # also to identify the last part of the rows
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount
# 26047  26047    Kolkata, India  22-Jun-14     Silver   Travel      F  128191
# 26048  26048       Pune, India   3-Aug-14  Signature   Travel      M  246316
# 26049  26049  Hyderabad, India  16-Jan-15     Silver   Travel      M  265019
# 26050  26050     Kanpur, India  14-Sep-14     Silver   Travel      M   88174
# 26051  26051  Hyderabad, India  19-Oct-13  Signature    Bills      M  184410

# %%
crd.columns #to identify the columns
# Out:
# Index(['index', 'City', 'Date', 'Card Type', 'Exp Type', 'Gender', 'Amount'], dtype='object')

# %%
crd.T
# Out:
#                   0                      1                 2      \
# index                 0                      1                 2
# City       Delhi, India  Greater Mumbai, India  Bengaluru, India
# Date          29-Oct-14              22-Aug-14         27-Aug-14
# Card Type          Gold               Platinum            Silver
# Exp Type          Bills                  Bills             Bills
# Gender                F                      F                 F
# Amount            82475                  32555            101738
#
#                            3                 4             5      \
# index                          3                 4             5
# City       Greater Mumbai, India  Bengaluru, India  Delhi, India
# Date                   12-Apr-14          5-May-15      8-Sep-14
# Card Type              Signature              Gold        Silver
# Exp Type                   Bills             Bills         Bills
# ...

# %% [markdown]
# # Female

# %%
female = crd[crd['Gender']== 'F'] # to get all females in the data
female
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26039  26039          Kanpur, India  15-Dec-14     Silver   Travel      F
# 26040  26040       Hyderabad, India  26-Oct-13       Gold   Travel      F
# 26043  26043       Hyderabad, India  15-May-15     Silver   Travel      F
# 26045  26045         Kolkata, India  26-Feb-14  Signature   Travel      F
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
meanf = sum(female.Amount) / len(female.Amount) # Get the mean of the amounts in credit cards for only females
print("credit cards of females Mean:", meanf)
# Out:
# credit cards of females Mean: 161206.9466374269

# %%
female.Amount.mean() # this also
# Out:
# 161206.9466374269

# %%
sort = sorted(female.Amount) # sort the amounts
n = len(sort) #legnth of the sorted

if n % 2 == 0:

    median = (sort[n//2 - 1] + sort[n//2]) / 2
else:
    median = sort[n//2]

print("Median Amounts of Female:", median)
# Out:
# Median Amounts of Female: 154797.0

# %%
female.Amount.mode()
# Out:
# 0     15779
# 1     17578
# 2    211653
# 3    215046
# 4    230105
# 5    262261
# Name: Amount, dtype: int64

# %%
female.Amount.sum() # total amount of all females in the credits
# Out:
# 2205311030

# %%
goldfemale = female[female['Card Type']== 'Gold'] # Gold Users for females
goldfemale
# Out:
#        index                   City       Date Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14      Gold    Bills      F
# 4          4       Bengaluru, India   5-May-15      Gold    Bills      F
# 6          6           Delhi, India  24-Feb-15      Gold    Bills      F
# 12        12  Greater Mumbai, India   7-Aug-14      Gold    Bills      F
# 17        17  Greater Mumbai, India  30-Mar-15      Gold    Bills      F
# ...      ...                    ...        ...       ...      ...    ...
# 26010  26010       Hyderabad, India  14-Apr-15      Gold   Travel      F
# 26016  26016         Chennai, India  11-Mar-15      Gold   Travel      F
# 26020  26020         Kolkata, India  16-Nov-14      Gold   Travel      F
# 26022  26022          Kanpur, India  24-Sep-14      Gold   Travel      F
# 26040  26040       Hyderabad, India  26-Oct-13      Gold   Travel      F
#
#        Amount
# 0       82475
# 4      171574
# 6      143250
# 12      19226
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
goldfemale.groupby('Exp Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#this for female

# %% [markdown]
# # MALE

# %%
male = crd[crd['Gender']== 'M']
male
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 1439    1439  Greater Mumbai, India  23-Dec-13       Gold     Food      M
# 1441    1441  Greater Mumbai, India  22-Jul-14  Signature     Food      M
# 1443    1443       Ahmedabad, India   1-May-14   Platinum     Food      M
# 1447    1447       Bengaluru, India   9-Dec-14       Gold     Food      M
# 1448    1448       Ahmedabad, India   8-Sep-14       Gold     Food      M
# ...      ...                    ...        ...        ...      ...    ...
# 26046  26046       Hyderabad, India   9-Oct-13  Signature   Travel      M
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 1439   260246
# 1441   155937
# 1443    61531
# 1447    46535
# ...

# %%
meanm = sum(male.Amount) / len(male.Amount) # Get the mean of the amounts in credit cards for only males
print("credit cards of male Mean:", meanm)
# Out:
# credit cards of male Mean: 151109.14508567733

# %%
male.Amount.mean() # or this one
# Out:
# 151109.14508567733

# %%
sort = sorted(male.Amount) # sort the amounts
n = len(sort) #legnth of the sorted

if n % 2 == 0:

    median = (sort[n//2 - 1] + sort[n//2]) / 2
else:
    median = sort[n//2]

print("Median Amounts:", median)
# Out:
# Median Amounts: 151242.0

# %%
Goldusers = male[male['Card Type']== 'Gold'] # to get the gold card holders of males
Goldusers
# Out:
#        index                   City       Date Card Type Exp Type Gender  \
# 1439    1439  Greater Mumbai, India  23-Dec-13      Gold     Food      M
# 1447    1447       Bengaluru, India   9-Dec-14      Gold     Food      M
# 1448    1448       Ahmedabad, India   8-Sep-14      Gold     Food      M
# 1449    1449       Ahmedabad, India  20-Jan-14      Gold     Food      M
# 1459    1459           Delhi, India  30-Nov-13      Gold     Food      M
# ...      ...                    ...        ...       ...      ...    ...
# 26012  26012       Hyderabad, India  30-Dec-13      Gold   Travel      M
# 26013  26013         Kolkata, India  22-May-14      Gold   Travel      M
# 26026  26026         Chennai, India  16-May-14      Gold   Travel      M
# 26038  26038           Surat, India  19-May-15      Gold   Travel      M
# 26044  26044         Kolkata, India  14-Oct-14      Gold   Travel      M
#
#        Amount
# 1439   260246
# 1447    46535
# 1448   120827
# 1449   194872
# ...

# %%
mayayaman = Goldusers[Goldusers['Amount']>= 100000] # to get the p=male user that have gold card but their amount value is greater than 100k
mayayaman
# Out:
#        index                   City       Date Card Type Exp Type Gender  \
# 1439    1439  Greater Mumbai, India  23-Dec-13      Gold     Food      M
# 1448    1448       Ahmedabad, India   8-Sep-14      Gold     Food      M
# 1449    1449       Ahmedabad, India  20-Jan-14      Gold     Food      M
# 1461    1461       Bengaluru, India   9-Jul-14      Gold     Food      M
# 1481    1481  Greater Mumbai, India  15-Nov-14      Gold     Food      M
# ...      ...                    ...        ...       ...      ...    ...
# 25998  25998         Kolkata, India  29-Sep-14      Gold   Travel      M
# 26008  26008            Pune, India  18-Feb-14      Gold   Travel      M
# 26013  26013         Kolkata, India  22-May-14      Gold   Travel      M
# 26038  26038           Surat, India  19-May-15      Gold   Travel      M
# 26044  26044         Kolkata, India  14-Oct-14      Gold   Travel      M
#
#        Amount
# 1439   260246
# 1448   120827
# 1449   194872
# 1461   204192
# ...

# %%
from matplotlib import pyplot as plt
mayayaman['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
mayayaman.groupby('Exp Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import random

random.seed(0)
female['Borrowed Amount'] = [round(random.random()*1000000, -3) for _ in range(5)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-50d0a1175f29> in <cell line: 4>()
#       2
#       3 random.seed(0)
# ----> 4 female['Borrowed Amount'] = [round(random.random()*1000000, -3) for _ in range(5)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
# ...
